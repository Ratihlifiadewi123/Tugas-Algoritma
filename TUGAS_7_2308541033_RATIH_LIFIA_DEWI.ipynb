# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import matplotlib.pyplot as plt

# Persamaan garis pertama melewati titik (r_33,a_33) dan (t_33,i_33)
r_33 = input("masukkan sebuah bilangan bulat sebagai titik di sb x : ") #Titik (r_33,a_33)
a_33 = input("masukkan sebuah bilangan bulat sebagai titik di sb y : ")
t_33 = input("masukkan sebuah bilangan bulat sebagai titik di sb x : ") #Titik (t_33,i_33)
i_33 = input("masukkan sebuah bilangan bulat sebagai titik di sb y : ")
ya_33 = int(i_33) - int(a_33) 
xa_33 = int(t_33) - int(r_33)
m1_33 = ya_33 / xa_33
print("Gradien garis pertama adalah {}".format(m1_33))
print("Persamaan garis pertama adalah y={}x+{} ".format(m1_33, float(-m1_33)* int(r_33) + int(a_33)))
#y1_33 = m1_33*(x_33-r_33)+a_33

# Persamaan garis kedua melewati titik (l_33,f_33) dan (d_33,w_33)
l_33 = input("masukkan sebuah bilangan bulat sebagai titik di sb x : ") #Titik (l_33,f_33)
f_33 = input("masukkan sebuah bilangan bulat sebagai titik di sb y : ")
d_33 = input("masukkan sebuah bilangan bulat sebagai titik di sb x : ")  #Titik (d_33,w_33)
w_33 = input("masukkan sebuah bilangan bulat sebagai titik di sb y : ")
yb_33 = int(w_33) - int(f_33)
xb_33 = int(d_33) - int(l_33)
m2_33 = yb_33 / xb_33
print("Gradien garis ke dua adalah {}".format(m2_33))
print("Persamaan garis kedua adalah y={}x+{} ".format(m2_33,float(-m2_33)* int(l_33)+int(f_33)))
#y2_33=m2_33*(x_33-l_33)+f_33

if m1_33 == m2_33:
    print("Gradien memiliki nilai yang sama sehingga tidak memiliki solusi.")
else:
    # Titik potong kedua garis pada (tp_x_33,tp_y_33)
    tp_x_33 = (int(m1_33)* int(r_33)- int(a_33) -float(m2_33)*int(l_33)+int(f_33)/(float(m1_33)-float(m2_33)))
    tp_y_33 = float(m2_33)*(float(tp_x_33)-int(l_33)+int(f_33))

    print("Titik potong ({},{})".format(tp_x_33,tp_y_33))
    
    h_33 = input("masukkan angka yang kamu inginkan untuk menentukan batas ")
    x_33 = np.arange(float(tp_x_33)-int(h_33),float(tp_x)+int(h_33),0.05)
    plt.figure(figsize=(6,6),dpi=100)
    
    plt.plot(x_33,m1_33*(x_33-int(r_33)+int(a_33)))
    plt.plot(x_33,m2_33*(x_33-int(l_33)+int(f_33)))
    plt.plot(tp_x_33,tp_y_33) 
    plt.legend(loc='best')
    plt.show()
# Out:
# masukkan sebuah bilangan bulat sebagai titik di sb x :  1
# masukkan sebuah bilangan bulat sebagai titik di sb y :  2
# masukkan sebuah bilangan bulat sebagai titik di sb x :  3
# masukkan sebuah bilangan bulat sebagai titik di sb y :  4
# Gradien garis pertama adalah 1.0
# Persamaan garis pertama adalah y=1.0x+1.0
# masukkan sebuah bilangan bulat sebagai titik di sb x :  1
# masukkan sebuah bilangan bulat sebagai titik di sb y :  2
# masukkan sebuah bilangan bulat sebagai titik di sb x :  3
# masukkan sebuah bilangan bulat sebagai titik di sb y :  4
# Gradien garis ke dua adalah 1.0
# Persamaan garis kedua adalah y=1.0x+1.0
# Gradien memiliki nilai yang sama sehingga tidak memiliki solusi.

# %%
# import numpy as np
import matplotlib.pyplot as plt

# Persamaan garis pertama melewati titik (r_33,a_33) dan (t_33,i_33)
r_33 = input("masukkan sebuah bilangan bulat sebagai titik di sb x : ") #Titik (r_33,a_33)
a_33 = input("masukkan sebuah bilangan bulat sebagai titik di sb y : ")
t_33 = input("masukkan sebuah bilangan bulat sebagai titik di sb x : ") #Titik (t_33,i_33)
i_33 = input("masukkan sebuah bilangan bulat sebagai titik di sb y : ")
ya_33 = int(i_33) - int(a_33) 
xa_33 = int(t_33) - int(r_33)
m1_33 = ya_33 / xa_33
print("Gradien garis pertama adalah {}".format(m1_33))
print("Persamaan garis pertama adalah y={}x+{} ".format(m1_33, float(-m1_33)* int(r_33) + int(a_33)))
#y1_33 = m1_33*(x_33-r_33)+a_33

# Persamaan garis kedua melewati titik (l_33,f_33) dan (d_33,w_33)
l_33 = input("masukkan sebuah bilangan bulat sebagai titik di sb x : ") #Titik (l_33,f_33)
f_33 = input("masukkan sebuah bilangan bulat sebagai titik di sb y : ")
d_33 = input("masukkan sebuah bilangan bulat sebagai titik di sb x : ")  #Titik (d_33,w_33)
w_33 = input("masukkan sebuah bilangan bulat sebagai titik di sb y : ")
yb_33 = int(w_33) - int(f_33)
xb_33 = int(d_33) - int(l_33)
m2_33 = yb_33 / xb_33
print("Gradien garis ke dua adalah {}".format(m2_33))
print("Persamaan garis kedua adalah y={}x+{} ".format(m2_33,float(-m2_33)* int(l_33)+int(f_33)))
#y2_33=m2_33*(x_33-l_33)+f_33

if m1_33 == m2_33:
    print("Gradien memiliki nilai yang sama sehingga tidak memiliki solusi.")
else:
    # Titik potong kedua garis pada (tp_x_33,tp_y_33)
    tp_x_33 = (int(m1_33)* int(r_33)- int(a_33) -float(m2_33)*int(l_33)+int(f_33)/(float(m1_33)-float(m2_33)))
    tp_y_33 = float(m2_33)*(float(tp_x_33)-int(l_33)+int(f_33))

    print("Titik potong ({},{})".format(tp_x_33,tp_y_33))
    
    h_33 = input("masukkan angka yang kamu inginkan untuk menentukan batas ")
    x_33 = np.arange(-int(h_33),int(h_33))
    y_33 = np.arange(-int(h_33),int(h_33))
    plt.figure(figsize=(6,6),dpi=100)
    
    plt.plot(x_33,m1_33*(x_33-int(r_33)+int(a_33)))
    plt.plot(x_33,m2_33*(x_33-int(l_33)+int(f_33)))
    plt.plot(tp_x_33,tp_y_33) 
    plt.legend(loc='best')
    plt.show()
# Out:
# masukkan sebuah bilangan bulat sebagai titik di sb x :  6
# masukkan sebuah bilangan bulat sebagai titik di sb y :  3
# masukkan sebuah bilangan bulat sebagai titik di sb x :  7
# masukkan sebuah bilangan bulat sebagai titik di sb y :  2
# Gradien garis pertama adalah -1.0
# Persamaan garis pertama adalah y=-1.0x+9.0
# masukkan sebuah bilangan bulat sebagai titik di sb x :  9
# masukkan sebuah bilangan bulat sebagai titik di sb y :  5
# masukkan sebuah bilangan bulat sebagai titik di sb x :  3
# masukkan sebuah bilangan bulat sebagai titik di sb y :  6
# Gradien garis ke dua adalah -0.16666666666666666
# Persamaan garis kedua adalah y=-0.16666666666666666x+6.5
# Titik potong (-13.5,2.9166666666666665)
# masukkan angka yang kamu inginkan untuk menentukan batas  3
