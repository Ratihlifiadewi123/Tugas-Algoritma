# %%
# Jika diketahui bahwa n adalah dua digit terakhir dari NIM kalian,
# maka tentukan biangan prima antara 1000𝑛 dan 1000(𝑛+1)

# %%
import math

# Ganti n dengan dua digit terakhir dari NIM Anda
n_33 = int(input("Masukkan dua digit terakhir dari NIM: "))
awal_33 = 1000 * n_33
akhir_33 = 1000 * (n_33 + 1)

def bilangan_prima_33(bilangan_33):
    if bilangan_33 <= 1:
        return False
    if bilangan_33 == 2:
        return True  # karena 2 adalah bilangan prima
    if bilangan_33 % 2 == 0:
        return False  # bilangan kelipatan dua merupakan bilangan yang bukan prima, kecuali angka 2
    
    # Periksa faktor ganjil hingga akar kuadrat dari bilangan
    akar_33 = int(math.sqrt(bilangan_33)) + 1
    for i_33 in range(3, akar_33, 2):
        if bilangan_33 % i_33 == 0:
            return False 
    return True

def mencari_prima_33(n_33):
    awal_33 = 1000 * n_33
    akhir_33 = 1000 * (n_33 + 1)
    prima_33 = [ ]
    
    for bilangan_33 in range(awal_33, akhir_33):
        if bilangan_prima_33(bilangan_33):
            prima_33.append(bilangan_33)
    return prima_33

angka_prima_33 = mencari_prima_33(n)
print(f"Bilangan prima antara {awal_33} dan {akhir_33} untuk n = {n_33} adalah:")
print(angka_prima_33)
print(f"Jumlah bilangan prima ada {len(angka_prima_33)}")
# Out:
# Masukkan dua digit terakhir dari NIM:  33
# Bilangan prima antara 33000 dan 34000 untuk n = 33 adalah:
# [33013, 33023, 33029, 33037, 33049, 33053, 33071, 33073, 33083, 33091, 33107, 33113, 33119, 33149, 33151, 33161, 33179, 33181, 33191, 33199, 33203, 33211, 33223, 33247, 33287, 33289, 33301, 33311, 33317, 33329, 33331, 33343, 33347, 33349, 33353, 33359, 33377, 33391, 33403, 33409, 33413, 33427, 33457, 33461, 33469, 33479, 33487, 33493, 33503, 33521, 33529, 33533, 33547, 33563, 33569, 33577, 33581, 33587, 33589, 33599, 33601, 33613, 33617, 33619, 33623, 33629, 33637, 33641, 33647, 33679, 33703, 33713, 33721, 33739, 33749, 33751, 33757, 33767, 33769, 33773, 33791, 33797, 33809, 33811, 33827, 33829, 33851, 33857, 33863, 33871, 33889, 33893, 33911, 33923, 33931, 33937, 33941, 33961, 33967, 33997]
# Jumlah bilangan prima ada 100

# %%
n_33 = int(input("Masukkan dua digit terakhir dari NIM: "))
awal_33 = 1000 * n_33 
akhir_33 = 1000 * (n_33 + 1)

prima_33 = range(awal_33, akhir_33)

print ("Bilangan prima di antara ", awal_33, " dan ", akhir_33, ":")
for i_33 in prima_33:
    if i_33 > 1:
        for a_33 in range(2, i_33):
            if (i_33 % a_33) == 0:
                break
        else:
            print(i_33)
# Out:
# Masukkan dua digit terakhir dari NIM:  33
# Bilangan prima di antara  33000  dan  34000 :
# 33013
# 33023
# 33029
# 33037
# 33049
# 33053
# 33071
# 33073
# 33083
# 33091
# 33107
# 33113
# 33119
# 33149
# 33151
# 33161
# 33179
# 33181
# 33191
# 33199
# 33203
# 33211
# 33223
# 33247
# 33287
# 33289
# 33301
# 33311
# 33317
# 33329
# 33331
# 33343
# 33347
# 33349
# 33353
# 33359
# 33377
# 33391
# 33403
# 33409
# 33413
# 33427
# 33457
# 33461
# 33469
# 33479
# 33487
# 33493
# 33503
# 33521
# 33529
# 33533
# 33547
# 33563
# 33569
# 33577
# 33581
# 33587
# 33589
# 33599
# 33601
# 33613
# 33617
# 33619
# 33623
# 33629
# 33637
# 33641
# 33647
# 33679
# 33703
# 33713
# 33721
# 33739
# 33749
# 33751
# 33757
# 33767
# 33769
# 33773
# 33791
# 33797
# 33809
# 33811
# 33827
# 33829
# 33851
# 33857
# 33863
# 33871
# 33889
# 33893
# 33911
# 33923
# 33931
# 33937
# 33941
# 33961
# 33967
# 33997
