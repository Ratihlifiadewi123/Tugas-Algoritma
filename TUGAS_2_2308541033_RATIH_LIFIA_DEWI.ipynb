# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
nama_33 = "Ratih Lifia Dewi"
prodi_33 = "matematika"
tahun_33 = "2023"
fakultas_33 = "Matematika dan Ilmu Pengetahuan Alam"
print("Hallo, nama saya " + nama_33 + " dari program studi " + prodi_33 + " angkatan " + tahun_33 + " fakultas " + fakultas_33 + ".")
hari_33 = "rabu"
tanggal_33 = "20"
bulan_33 = "Maret"
matkul_33 = "Algoritma"
ruang_33 = "Lab K"
mulai_33 = "11.10"
akhir_33 = "13.50"
print(f"Pada {hari_33}, {tanggal_33} {bulan_33} {tahun_33} ada pembelajaran {matkul_33} di {ruang_33} dari jam {mulai_33} - {akhir_33} WITA")
# Out:
# Hallo, nama saya Ratih Lifia Dewi dari program studi matematika angkatan 2023 fakultas Matematika dan Ilmu Pengetahuan Alam.
# Pada rabu, 20 Maret 2023 ada pembelajaran Algoritma di Lab K dari jam 11.10 - 13.50 WITA

# %%
nama_33 = "Ratih Lifia Dewi"
print(nama_33[:])
print(nama_33[1:-7])
print(nama_33[0:3])
print(nama_33[2:4])
print(nama_33[2:-1:2])
print(nama_33[2:-1:3])
print(nama_33[2:-1:4])
print(nama_33[2:-1:5])
print(nama_33[2:-5:3])
angka_33 ="1,2,3,4,5,6,7,8,9,0"
print(angka_33[2:-2:4])
print(angka_33[1:-1:2])
print(angka_33[2:-1:2])
# Out:
# Ratih Lifia Dewi
# atih Lif
# Rat
# ti
# thLfaDw
# t f w
# tLaw
# tiD
# t f
# 2468
# ,,,,,,,,,
# 23456789

# %%
tema_33 = "Belajar Algoritma dan Struktur Data"
print(len(tema_33))
# Out:
# 35

# %%
tema_33 = "Belajar Algoritma dan Struktur Data"
tema_33.upper()
# Out:
# 'BELAJAR ALGORITMA DAN STRUKTUR DATA'

# %%
tema_33 = "Belajar Algoritma dan Struktur Data"
tema_33.lower()
# Out:
# 'belajar algoritma dan struktur data'

# %%
tema_33 = "Belajar Algoritma dan Struktur Data"
tema_33.find("u")
# Out:
# 25

# %%
tema_33 = "Belajar Algoritma dan Struktur Data"
tema_33.find("c")
# Out:
# -1

# %%
tema_33 = "Belajar Algoritma dan Struktur Data"
tema_33.replace("Belajar", "Mempelajari")
# Out:
# 'Mempelajari Algoritma dan Struktur Data'

# %%
tema_33 = "Belajar Algoritma dan Struktur Data"
tema_33.replace("belajar", "Mempelajari")
# Out:
# 'Belajar Algoritma dan Struktur Data'

# %%
tema_33 = "Belajar Algoritma dan Struktur Data"
print("ajar" in tema_33)
# Out:
# True

# %%
tema_33 = "Belajar Algoritma dan Struktur Data"
print("algo" in tema_33)
# Out:
# False

# %%
satu_33 = print(10**10)
dua_33 = print(23*1000000000)
tiga_33 = print(23000000000+8541100)
empat_33 = print(23008541100-67)
x_33=99
x_33//=3
print(x_33)
# Out:
# 10000000000
# 23000000000
# 23008541100
# 23008541033
# 33

# %%
x_33 = 33 < 23
print (x_33)
x_33 = 10 == 8
print (x_33)
x_33 = 33 >= 23
print(x_33)
x_33 = 20 != 5
print(x_33)
# Out:
# False
# False
# True
# True

# %%
minggu_33 = 7
bulan_33 = 12
print(minggu_33 > 3 and bulan_33 > 10)
print(minggu_33 < 8 and bulan_33 > 20)
print(minggu_33 < 6 and bulan_33 > 24)
print(minggu_33 < 5 or bulan_33 > 15)
print(minggu_33 < 9 or bulan_33 < 2)
print(minggu_33 > 1 or bulan_33 > 4)
# Out:
# True
# False
# False
# False
# True
# True
