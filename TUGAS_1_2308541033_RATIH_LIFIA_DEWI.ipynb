# %%
tebak_33 = "Apapun angka yang akan kamu pilih, jawaban yang diperoleh pasti angka 3"
print(tebak_33)
angka_satu_33 = input("Masukkan angka yang diinginkan dari 1 sampai 10 : ")
angka_dua_33 = "2"
angka_tiga_33 = "5"
angka_empat_33 = angka_satu_33
angka_lima_33 = "7"
jumlah_satu_33 = float(angka_satu_33) * float(angka_dua_33)
jumlah_dua_33 = float(str(jumlah_satu_33)) * float(angka_tiga_33) 
jumlah_tiga_33 = float(str(jumlah_dua_33)) / float(angka_empat_33)
jumlah_empat_33 = float(str(jumlah_tiga_33)) - float(angka_lima_33)
print("Kalikan dengan angka " + angka_dua_33)
print("Kalikan hasilnya dengan angka " + angka_tiga_33)
print("Bagi dengan angka " + angka_empat_33)
print("Kurangi dengan angka " + angka_lima_33)
jeda_33 = input("Apakah kamu sudah selesai menghitung : ")
print("Hasilnya pasti angka " + str(jumlah_empat_33) + " kan")
# Out:
# Apapun angka yang akan kamu pilih, jawaban yang diperoleh pasti angka 3
# Masukkan angka yang diinginkan dari 1 sampai 10 :  1
# Kalikan dengan angka 2
# Kalikan hasilnya dengan angka 5
# Bagi dengan angka 1
# Kurangi dengan angka 7
# Apakah kamu sudah selesai menghitung :  2
# Hasil jawabannya pasti angka 3.0 kan

# %%
angka_33 = "Pilihlah satu angka dari 1 sampai 9"
masuk_33 = float(input("Angka yang kamu pilih adalah "))
if masuk_33 <= 6:
    print("Kamu menebak angka yang salah")
    print("Silahkan coba lagi ya^^")
if masuk_33 >= 8:
    print("Aduh kamu salah menebak")
    print("Coba lagi sampai kamu menebak angka yang benar")
    print("Semoga berhasil^^")
if masuk_33 == 7:
    print("Horeeee tebakanmu benar")
    print("Keberuntungan memihakmu^0^")
    akhir_33 = input("Berapa kali percobaan kamu dapat menebak angka dengan benar? ")
    print("Waw kamu hebat sekali dapat menebak dalam " + akhir_33 + " kali percobaan dengan benar")
# Out:
# Angka yang kamu pilih adalah  7
# Horeeee tebakanmu benar
# Keberuntungan memihakmu^0^
# Berapa kali percobaan kamu dapat menebak angka dengan benar?  5
# Waw kamu hebat sekali dapat menebak dalam 5 kali percobaan dengan benar
